# %%
# %env PYTHONPATH = # /env/python
# Out:
# env: PYTHONPATH=# /env/python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and install and update miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !./Miniconda3-py39_23.3.1-0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update -q conda
# Out:
# --2024-10-29 04:55:03--  https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70605094 (67M) [application/x-sh]
# Saving to: ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh’
#
# Miniconda3-py39_23. 100%[===================>]  67.33M   124MB/s    in 0.5s
#
# 2024-10-29 04:55:03 (124 MB/s) - ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh’ saved [70605094/70605094]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages
#
#
# Downloading and Extracting Packages
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py39h6a678d5_8         359 KB
#     ca-certificates-2024.9.24  |       h06a4308_0         130 KB
#     certifi-2024.8.30          |   py39h06a4308_0         162 KB
#     cffi-1.17.1                |   py39h1fdaa30_0         252 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda-package-handling-2.3.0|   py39h06a4308_0         269 KB
#     conda-package-streaming-0.10.0|   py39h06a4308_0          27 KB
#     cryptography-43.0.0        |   py39hdda0065_0         2.2 MB
#     idna-3.7                   |   py39h06a4308_0         113 KB
#     jsonpatch-1.33             |   py39h06a4308_1          31 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     packaging-24.1             |   py39h06a4308_0         147 KB
#     pycosat-0.6.6              |   py39h5eee18b_1          93 KB
#     pyopenssl-24.2.1           |   py39h06a4308_0          96 KB
#     python-3.9.20              |       he870216_1        25.1 MB
#     requests-2.32.3            |   py39h06a4308_0          99 KB
#     ruamel.yaml.clib-0.2.8     |   py39h5eee18b_0         158 KB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     tqdm-4.66.5                |   py39h2f386ee_0         133 KB
#     tzdata-2024b               |       h04d1e81_0         115 KB
#     urllib3-2.2.3              |   py39h06a4308_0         180 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     zstandard-0.23.0           |   py39h2c38b39_0         432 KB
#     zstd-1.5.6                 |       hc292b87_0         664 KB
#     ------------------------------------------------------------
#                                            Total:        42.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py39h6a678d5_8
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   zstd               pkgs/main/linux-64::zstd-1.5.6-hc292b87_0
#
# The following packages will be REMOVED:
#
#   brotlipy-0.7.0-py39h27cfd23_1003
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-h06a4308_0 --> 2024.9.24-h06a4308_0
#   certifi                          2022.12.7-py39h06a4308_0 --> 2024.8.30-py39h06a4308_0
#   cffi                                1.15.1-py39h5eee18b_3 --> 1.17.1-py39h1fdaa30_0
#   charset-normalizer                     2.0.4-pyhd3eb1b0_0 --> 3.3.2-pyhd3eb1b0_0
#   conda-package-han~                   2.0.2-py39h06a4308_0 --> 2.3.0-py39h06a4308_0
#   conda-package-str~                   0.7.0-py39h06a4308_0 --> 0.10.0-py39h06a4308_0
#   cryptography                        39.0.1-py39h9ce1e76_0 --> 43.0.0-py39hdda0065_0
#   idna                                   3.4-py39h06a4308_0 --> 3.7-py39h06a4308_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/linux-64::jsonpatch-1.33-py39h06a4308_1
#   ld_impl_linux-64                          2.38-h1181459_1 --> 2.40-h12ee557_0
#   libffi                                   3.4.2-h6a678d5_6 --> 3.4.4-h6a678d5_1
#   openssl                                 1.1.1t-h7f8727e_0 --> 3.0.15-h5eee18b_0
#   packaging                             23.0-py39h06a4308_0 --> 24.1-py39h06a4308_0
#   pycosat                              0.6.4-py39h5eee18b_0 --> 0.6.6-py39h5eee18b_1
#   pyopenssl                           23.0.0-py39h06a4308_0 --> 24.2.1-py39h06a4308_0
#   python                                  3.9.16-h7a1cb2a_2 --> 3.9.20-he870216_1
#   requests                            2.28.1-py39h06a4308_1 --> 2.32.3-py39h06a4308_0
#   ruamel.yaml.clib                     0.2.6-py39h5eee18b_1 --> 0.2.8-py39h5eee18b_0
#   sqlite                                  3.41.1-h5eee18b_0 --> 3.45.3-h5eee18b_0
#   tk                                      8.6.12-h1ccaba5_0 --> 8.6.14-h39e8969_0
#   tqdm                                4.65.0-py39hb070fc8_0 --> 4.66.5-py39h2f386ee_0
#   tzdata                                   2023c-h04d1e81_0 --> 2024b-h04d1e81_0
#   urllib3                            1.26.15-py39h06a4308_0 --> 2.2.3-py39h06a4308_0
#   xz                                      5.2.10-h5eee18b_1 --> 5.4.6-h5eee18b_1
#   zlib                                    1.2.13-h5eee18b_0 --> 1.2.13-h5eee18b_1
#   zstandard                           0.19.0-py39h5eee18b_0 --> 0.23.0-py39h2c38b39_0
#
#
# Proceed ([y]/n)? y
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
# Create conda environment with python 3.9
# !conda create -n myenv python=3.9
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.9.2
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-24.2                   |   py39h06a4308_0         2.2 MB
#     setuptools-75.1.0          |   py39h06a4308_0         1.7 MB
#     wheel-0.44.0               |   py39h06a4308_0         108 KB
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.9.24-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.15-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-24.2-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.20-he870216_1
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.1.0-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   tzdata             pkgs/main/noarch::tzdata-2024b-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.44.0-py39h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# wheel-0.44.0         | 108 KB    | :   0% 0/1 [00:00<?, ?it/s]
# pip-24.2             | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# setuptools-75.1.0    | 1.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
# pip-24.2             | 2.2 MB    | :   3% 0.02837540255783887/1 [00:00<00:03,  3.73s/it]
#
# wheel-0.44.0         | 108 KB    | :  15% 0.14767544571232852/1 [00:00<00:00,  1.13s/it]
# pip-24.2             | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
# wheel-0.44.0         | 108 KB    | : 100% 1.0/1 [00:00<00:00,  1.09it/s]
#
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.08it/s]
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# Install dependencies in the new environment. You need to force acitvate conda everytime
# %%shell
eval "$(conda shell.bash hook)"
conda activate myenv
pip install -q tflite-model-maker
pip install -q pycocotools
pip install -q ipykernel
pip install -q numpy
pip install seaborn
pip install pycryptodome
pip install firebase-admin
pip install protobuf==3.20.*
pip install matplotlib
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 580.1/580.1 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 117.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 96.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 47.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 92.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 98.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 100.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 126.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 108.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 79.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 130.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 42.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 140.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 109.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 111.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 72.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 91.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 130.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 38.0 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
#   Building wheel for kaggle (setup.py) ... done
#   Building wheel for promise (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.1/862.1 kB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.0 MB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/envs/myenv/lib/python3.9/site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: pandas>=1.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Collecting pycryptodome
#   Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 54.7 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.21.0
# Collecting firebase-admin
#   Downloading firebase_admin-6.5.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting cachecontrol>=0.12.6 (from firebase-admin)
#   Downloading cachecontrol-0.14.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/envs/myenv/lib/python3.9/site-packages (from firebase-admin) (2.149.0)
# Collecting google-cloud-storage>=1.37.1 (from firebase-admin)
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting pyjwt>=2.5.0 (from pyjwt[crypto]>=2.5.0->firebase-admin)
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.22.0)
# Collecting google-cloud-firestore>=2.9.1 (from firebase-admin)
#   Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from cachecontrol>=0.12.6->firebase-admin) (2.32.3)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.12.6->firebase-admin)
#   Downloading msgpack-1.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (3.19.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.35.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.67.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.48.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-cloud-firestore>=2.9.1->firebase-admin) (2.4.1)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.6.0)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.5.0->firebase-admin)
#   Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/envs/myenv/lib/python3.9/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2024.8.30)
# Requirement already satisfied: pycparser in /usr/local/envs/myenv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Downloading firebase_admin-6.5.0-py3-none-any.whl (126 kB)
# Downloading cachecontrol-0.14.0-py3-none-any.whl (22 kB)
# Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl (336 kB)
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 38.6 MB/s eta 0:00:00
# Downloading msgpack-1.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (377 kB)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Installing collected packages: pyjwt, protobuf, msgpack, cryptography, cachecontrol, google-cloud-storage, google-cloud-firestore, firebase-admin
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.4 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.0 requires protobuf<4,>=3.13, but you have protobuf 5.28.3 which is incompatible.
# tflite-support 0.4.4 requires protobuf<4,>=3.18.0, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed cachecontrol-0.14.0 cryptography-43.0.3 firebase-admin-6.5.0 google-cloud-firestore-2.19.0 google-cloud-storage-2.18.2 msgpack-1.1.0 protobuf-5.28.3 pyjwt-2.9.0
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (679 bytes)
# Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.9 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.4 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3
# Requirement already satisfied: matplotlib in /usr/local/envs/myenv/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.16 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Run your training and eval script as an external python script
# %%shell
eval "$(conda shell.bash hook)"
conda activate myenv
python /content/drive/My\ Drive/Friday_python/trun.py
# Out:
# 2024-10-29 05:14:20.161349: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-10-29 05:14:20.161392: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/local/envs/myenv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/envs/myenv/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# TensorFlow Version: 2.8.4
# Model Maker Version: 0.4.3
# Deleted local folder: /content/friday/
# Deleted Realtime Database entry for: vbbOQBAlWeXPtJOvdZ81IMbIS7v1
# Downloaded: /content/friday/AIname_recording1297427694.wav
# Downloaded: /content/friday/AIname_recording169456027.wav
# Downloaded: /content/friday/AIname_recording1783757285.wav
# Downloaded: /content/friday/AIname_recording1884226909.wav
# Downloaded: /content/friday/AIname_recording220483229.wav
# Downloaded: /content/friday/AIname_recording251940458.wav
# Downloaded: /content/friday/AIname_recording400016063.wav
# Downloaded: /content/friday/AIname_recording584504819.wav
# Downloaded: /content/friday/AIname_recording686997243.wav
# Downloaded: /content/friday/AIname_recording822074070.wav
# Deleted local folder: /content/dataset-speech/vigor/
# Total number of files in /content/dataset-speech/vigor: 200
# Directory exists
# Total number of files in /content/dataset-speech/vigor: 200
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2024-10-29 05:14:27.957634: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-10-29 05:14:27.958019: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.9/site-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2024-10-29 05:14:27.958175: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.9/site-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2024-10-29 05:14:27.958330: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.9/site-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2024-10-29 05:14:27.958470: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.9/site-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2024-10-29 05:14:28.008916: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.9/site-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2024-10-29 05:14:28.009304: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-10-29 05:14:28.009679: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 42, 225, 8)        136
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 112, 8)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 109, 32)       2080
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 54, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 9, 51, 32)         8224
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 25, 32)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 22, 32)         8224
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 11, 32)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 704)               0
#
#  dropout_1 (Dropout)         (None, 704)               0
#
#  dense_1 (Dense)             (None, 2000)              1410000
#
#  dropout_2 (Dropout)         (None, 2000)              0
#
#  classification_head (Dense)  (None, 7)                14007
#
# =================================================================
# Total params: 1,442,671
# Trainable params: 14,007
# Non-trainable params: 1,428,664
# _________________________________________________________________
# Epoch 1/15
# 65/65 [==============================] - 99s 1s/step - loss: 1.3619 - acc: 0.6192 - val_loss: 0.2938 - val_acc: 0.9016
# Epoch 2/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.5291 - acc: 0.8413 - val_loss: 0.2292 - val_acc: 0.9213
# Epoch 3/15
# 65/65 [==============================] - 2s 30ms/step - loss: 0.3513 - acc: 0.8760 - val_loss: 0.2276 - val_acc: 0.9252
# Epoch 4/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.2813 - acc: 0.9000 - val_loss: 0.2294 - val_acc: 0.9291
# Epoch 5/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.2925 - acc: 0.8990 - val_loss: 0.2172 - val_acc: 0.9370
# Epoch 6/15
# 65/65 [==============================] - 3s 46ms/step - loss: 0.2352 - acc: 0.9202 - val_loss: 0.2109 - val_acc: 0.9409
# Epoch 7/15
# 65/65 [==============================] - 3s 52ms/step - loss: 0.2108 - acc: 0.9308 - val_loss: 0.2159 - val_acc: 0.9449
# Epoch 8/15
# 65/65 [==============================] - 2s 31ms/step - loss: 0.1742 - acc: 0.9471 - val_loss: 0.2185 - val_acc: 0.9370
# Epoch 9/15
# 65/65 [==============================] - 2s 34ms/step - loss: 0.1356 - acc: 0.9538 - val_loss: 0.2151 - val_acc: 0.9370
# Epoch 10/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.1219 - acc: 0.9529 - val_loss: 0.2156 - val_acc: 0.9370
# Epoch 11/15
# 65/65 [==============================] - 2s 34ms/step - loss: 0.1213 - acc: 0.9529 - val_loss: 0.2382 - val_acc: 0.9252
# Epoch 12/15
# 65/65 [==============================] - 3s 41ms/step - loss: 0.1369 - acc: 0.9558 - val_loss: 0.2337 - val_acc: 0.9173
# Epoch 13/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.1267 - acc: 0.9615 - val_loss: 0.2566 - val_acc: 0.9252
# Epoch 14/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.1032 - acc: 0.9635 - val_loss: 0.2556 - val_acc: 0.9213
# Epoch 15/15
# 65/65 [==============================] - 2s 29ms/step - loss: 0.1068 - acc: 0.9644 - val_loss: 0.2327 - val_acc: 0.9252
# 2024-10-29 05:16:44.813604: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2024-10-29 05:16:46.203403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-10-29 05:16:46.203625: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 05:16:46.203764: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-10-29 05:16:46.206281: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-10-29 05:16:46.206446: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-10-29 05:16:46.356744: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1164] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 225 nodes (167), 367 edges (297), time = 7.159ms.
#   function_optimizer: Graph size after: 225 nodes (0), 367 edges (0), time = 3.6ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_true_663_104
#   function_optimizer: function_optimizer did nothing. time = 0.007ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_false_96_180
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_cond_true_217_208
#   function_optimizer: Graph size after: 9 nodes (0), 10 edges (0), time = 0.228ms.
#   function_optimizer: Graph size after: 9 nodes (0), 10 edges (0), time = 0.192ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_true_298_41
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_true_95_116
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_1_AssertGuard_true_114_192
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_1_AssertGuard_false_115_86
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_false_664_174
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_cond_false_218_162
#   function_optimizer: Graph size after: 15 nodes (0), 14 edges (0), time = 0.294ms.
#   function_optimizer: Graph size after: 15 nodes (0), 14 edges (0), time = 0.266ms.
# Optimization results for grappler item: __inference_cond_Assert_AssertGuard_false_225_73
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_cond_Assert_AssertGuard_true_224_198
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_true_197_186
#   function_optimizer: function_optimizer did nothing. time = 0.003ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_false_299_47
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_cond_Assert_AssertGuard_true_249_110
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_cond_Assert_AssertGuard_false_250_146
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# Optimization results for grappler item: __inference_Assert_AssertGuard_false_198_18
#   function_optimizer: function_optimizer did nothing. time = 0.002ms.
#   function_optimizer: function_optimizer did nothing. time = 0.001ms.
#
# 2024-10-29 05:16:46.614575: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2024-10-29 05:16:46.614624: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# Model uploaded to: gs://foregroundservice-10348.appspot.com/users/vbbOQBAlWeXPtJOvdZ81IMbIS7v1/model/browserfft-speech.tflite
# Realtime Database updated for user vbbOQBAlWeXPtJOvdZ81IMbIS7v1.
